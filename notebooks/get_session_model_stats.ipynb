# %% [markdown]
# Problem:
#
# - We observe that the R^2 of datasets other than Churchland Shenoy (CS) are low in comparison to what's achievable in POSSM.
# - We observe that the overall R^2 is still high despite this.
# - Thus leading to the hypothesis that the model's training is dominated by the CS dataset. We wish to investigate where the model is failing by conducting the following segmentation analysis:
#
# Slice by categories:
# 1. Within trial vs outside of trial
# 2. Movement phases
# 3. Task
#
# Metrics:
# 1. Total duration
# 2. Variance
# 3. MSE / R^2
#
# What happens if we scale the loss by the variance?
# 1. samples of lower variance will have higher penalties, vice versa.

# %%
from omegaconf import OmegaConf
from foundational_ssm.loaders import get_brainset_train_val_loaders
from foundational_ssm.utils import load_model_and_state_wandb
from foundational_ssm.constants import DATA_ROOT, parse_session_id
from tqdm import tqdm
import pandas as pd
import multiprocessing as mp

# %load_ext autoreload
# %autoreload 2

# %%
config_path = "/cs/student/projects1/ml/2024/mlaimon/foundational_ssm/configs/test_pretrain.yaml"
cfg = OmegaConf.load(config_path) 
train_dataset, _, val_dataset, _ = get_brainset_train_val_loaders(
    cfg.train_loader,
    cfg.val_loader,
    data_root='../'+DATA_ROOT
)
model_artifact_id = 'melinajingting-ucl/foundational_ssm_pretrain_decoding/possm_dataset_l1_d128_best_model:latest'
model, state = load_model_and_state_wandb(model_artifact_id)

train_sampling_intervals = train_dataset.get_sampling_intervals()
val_sampling_intervals = val_dataset.get_sampling_intervals()

mp.set_start_method("spawn", force=True)
window_length = 1
sampling_rate = 200

recording_metrics_list = []
# Out:
# wandb:   1 of 1 files downloaded.

# %% [markdown]
# Problem:
#
# - We observe that the R^2 of datasets other than Churchland Shenoy (CS) are low in comparison to what's achievable in POSSM.
# - We observe that the overall R^2 is still high despite this.
# - Thus leading to the hypothesis that the model's training is dominated by the CS dataset. We wish to investigate where the model is failing by conducting the following segmentation analysis:
#
# Slice by categories:
# 1. Within trial vs outside of trial
# 2. Movement phases
# 3. Task
#
# Metrics:
# 1. Total duration
# 2. Variance
# 3. MSE / R^2
#
# What happens if we scale the loss by the variance?
# 1. samples of lower variance will have higher penalties, vice versa.

# %%
import jax
from jax import random as jr
from jax import numpy as jnp
import numpy as np
from foundational_ssm.samplers import SequentialFixedWindowSampler
from foundational_ssm.collate import pad_collate
from functools import partial 
from torch.utils.data import DataLoader

def compute_variance_mse_r2(preds, targets):
    preds = preds.reshape(-1, preds.shape[-1])
    targets = targets.reshape(-1, targets.shape[-1]) 
    
    mse = jnp.mean((targets - preds) ** 2)         # Per-dimension MSE
    var = jnp.var(targets) 
    
    ss_res = jnp.sum((targets - preds) ** 2, axis=0) 
    ss_tot = jnp.sum((targets - jnp.mean(targets, axis=0)) ** 2, axis=0)
    r2_per_dim = 1 - ss_res / (ss_tot + 1e-8) # Add epsilon for stability
    return var, mse, jnp.mean(r2_per_dim)

def compute_interval_metrics(recording_data, sampling_intervals, model, state, window_length, sampling_rate, prefix='', rng_key = jr.PRNGKey(0)):
    #deterministic random key for the dropout. TODO: expose inference variable in S5Block all the way up to SSMFoundationalDecoder
    metrics = {}
    interval = list(sampling_intervals.values())[0]
    metrics[f'{prefix}total_duration'] = np.sum(interval.end - interval.start)
    metrics[f'{prefix}mean_duration']  = np.mean(interval.end - interval.start)
    try:
        sampler = SequentialFixedWindowSampler(sampling_intervals=sampling_intervals, window_length=window_length, drop_short=True)
        loader = DataLoader(
            dataset=recording_data,
            sampler=sampler,
            batch_size=256,
            collate_fn=partial(pad_collate, fixed_seq_len=int(window_length*sampling_rate)),
            num_workers=0,
            pin_memory=True,
            persistent_workers=False
        )
        all_preds = []
        all_targets = []
        for batch in loader:
            batch = {k: jax.device_put(np.array(v)) for k, v in batch.items()}
            inputs, targets, mask, dataset_group_idxs = batch.values()
            mask = mask[..., None]
            preds, state = jax.vmap(model, axis_name="batch", in_axes=(0, None, None, 0), out_axes=(0, None))(inputs, state, rng_key, dataset_group_idxs)
            
            all_preds.append(jnp.where(mask, preds, 0))
            all_targets.append(jnp.where(mask, targets, 0))
            
        all_preds = jnp.concatenate(all_preds, axis=0)
        all_targets = jnp.concatenate(all_targets, axis=0)
        var, mse, r2 = compute_variance_mse_r2(preds, targets)
    except:
        var, mse, r2 = np.nan, np.nan, np.nan 
    metrics.update({
        f'{prefix}var': var,
        f'{prefix}mse': mse,
        f'{prefix}r2': r2,
    }) 
    return metrics

# %%
for i, (recording_id, train_interval) in tqdm(enumerate(train_sampling_intervals.items())):
    recording_data = train_dataset.get_recording_data(recording_id) 
    intervals_dict = {'overall': train_interval}
    if hasattr(recording_data, 'trials'):
        
        intervals_dict['in_trial'] = train_interval & recording_data.trials
        intervals_dict['ex_trial'] = train_interval.difference(intervals_dict['in_trial'])
        
        if hasattr(recording_data.trials, 'is_valid'):
            intervals_dict['valid_trial'] = train_interval & recording_data.trials.select_by_mask(recording_data.trials.is_valid)
            intervals_dict['ex_valid_trial'] = intervals_dict['in_trial'].difference(intervals_dict['valid_trial'])
    
    if hasattr(recording_data, 'movement_phases'):
        for phase in recording_data.movement_phases.keys():
            intervals_dict[phase] = train_interval & getattr(recording_data.movement_phases, phase)
    
    dataset, subject, task = parse_session_id(recording_id)
    recording_metrics_dict = {
        'dataset':dataset,
        'session_id': recording_id.split('/')[1],
        'subject':subject,
        'task':task
    } 
    
    for interval_name, interval in intervals_dict.items():
        interval_metrics = compute_interval_metrics(train_dataset, {recording_id: interval}, model, state, window_length, sampling_rate, prefix=interval_name+'_')
        recording_metrics_dict.update(interval_metrics)
    recording_metrics_list.append(recording_metrics_dict)
    
    recording_metrics_df = pd.DataFrame(recording_metrics_list)
    recording_metrics_df.to_csv('recording_metrics.csv')
# Out:
# 0it [00:00, ?it/s]
# /tmp/ipykernel_1344907/1397548959.py:42: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   batch = {k: jax.device_put(np.array(v)) for k, v in batch.items()}
# WARNING:root:Skipping 1.959833333333279 seconds of data due to short intervals. Remaining: 467 seconds.
# WARNING:root:Skipping 0.3309666666666544 seconds of data due to short intervals. Remaining: 414 seconds.
# WARNING:root:Skipping 1.6288666666666245 seconds of data due to short intervals. Remaining: 53 seconds.
# WARNING:root:Skipping 27.007233333333062 seconds of data due to short intervals. Remaining: 0 seconds.
# /cs/student/projects1/ml/2024/mlaimon/anaconda3/envs/foundational_ssm/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:3859: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /cs/student/projects1/ml/2024/mlaimon/anaconda3/envs/foundational_ssm/lib/python3.13/site-packages/numpy/_core/_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# WARNING:root:Skipping 50.27999999999987 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 128.93880000000007 seconds of data due to short intervals. Remaining: 36 seconds.
# WARNING:root:Skipping 3.6459999999999777 seconds of data due to short intervals. Remaining: 423 seconds.
# 10it [16:13, 94.58s/it]WARNING:root:Skipping 1.5166333333332318 seconds of data due to short intervals. Remaining: 1098 seconds.
# WARNING:root:Skipping 1.5166333333332318 seconds of data due to short intervals. Remaining: 684 seconds.
# WARNING:root:Skipping 0.10826666666660989 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 0.4900000000000091 seconds of data due to short intervals. Remaining: 3 seconds.
# WARNING:root:Skipping 1.0710000000000264 seconds of data due to short intervals. Remaining: 269 seconds.
# 11it [18:20, 104.36s/it]WARNING:root:Skipping 1.1720000000000002 seconds of data due to short intervals. Remaining: 410 seconds.
# WARNING:root:Skipping 1.1720000000000002 seconds of data due to short intervals. Remaining: 20 seconds.
# WARNING:root:Skipping 0.10530000000013828 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 0.49 seconds of data due to short intervals. Remaining: 2 seconds.
# WARNING:root:Skipping 1.6594666666666598 seconds of data due to short intervals. Remaining: 260 seconds.
# 12it [20:19, 109.03s/it]WARNING:root:Skipping 4.271999999999991 seconds of data due to short intervals. Remaining: 704 seconds.
# WARNING:root:Skipping 0.44399999999996 seconds of data due to short intervals. Remaining: 395 seconds.
# WARNING:root:Skipping 3.8280000000000314 seconds of data due to short intervals. Remaining: 309 seconds.
# WARNING:root:Skipping 13.46719999999996 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 2.8163000000000125 seconds of data due to short intervals. Remaining: 816 seconds.
# 13it [21:58, 106.03s/it]WARNING:root:Skipping 3.076000000000036 seconds of data due to short intervals. Remaining: 566 seconds.
# WARNING:root:Skipping 0.6889999999999645 seconds of data due to short intervals. Remaining: 426 seconds.
# WARNING:root:Skipping 2.3870000000000715 seconds of data due to short intervals. Remaining: 140 seconds.
# WARNING:root:Skipping 13.769600000000157 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 0.6045666666665852 seconds of data due to short intervals. Remaining: 787 seconds.
# 14it [23:36, 103.58s/it]WARNING:root:Skipping 1.683999999999898 seconds of data due to short intervals. Remaining: 557 seconds.
# WARNING:root:Skipping 0.5079999999999245 seconds of data due to short intervals. Remaining: 403 seconds.
# WARNING:root:Skipping 1.1759999999999735 seconds of data due to short intervals. Remaining: 154 seconds.
# WARNING:root:Skipping 12.150666666666469 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 1.6419666666665762 seconds of data due to short intervals. Remaining: 767 seconds.
# 15it [25:00, 97.61s/it] WARNING:root:Skipping 2.7350000000001273 seconds of data due to short intervals. Remaining: 635 seconds.
# WARNING:root:Skipping 2.7350000000001273 seconds of data due to short intervals. Remaining: 208 seconds.
# WARNING:root:Skipping 13.15726666666702 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 2.6917666666667515 seconds of data due to short intervals. Remaining: 845 seconds.
# 16it [26:41, 98.63s/it]WARNING:root:Skipping 2.1649999999999636 seconds of data due to short intervals. Remaining: 763 seconds.
# WARNING:root:Skipping 2.1649999999999636 seconds of data due to short intervals. Remaining: 293 seconds.
# WARNING:root:Skipping 13.657033333333203 seconds of data due to short intervals. Remaining: 0 seconds.
# 17it [28:07, 94.69s/it]WARNING:root:Skipping 0.8329999999999984 seconds of data due to short intervals. Remaining: 535 seconds.
# WARNING:root:Skipping 0.8329999999999984 seconds of data due to short intervals. Remaining: 145 seconds.
# WARNING:root:Skipping 12.051966666666429 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 0
seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 8.82410000000084 seconds of data due to short intervals. Remaining: 2371 seconds.
# 25it [45:43, 140.63s/it]WARNING:root:Skipping 7.910999999999888 seconds of data due to short intervals. Remaining: 2676 seconds.
# WARNING:root:Skipping 7.910999999999888 seconds of data due to short intervals. Remaining: 1304 seconds.
# WARNING:root:Skipping 44.528799999999435 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 6.4790333333342005 seconds of data due to short intervals. Remaining: 2645 seconds.
# 26it [47:59, 139.11s/it]WARNING:root:Skipping 14.827999999999605 seconds of data due to short intervals. Remaining: 2498 seconds.
# WARNING:root:Skipping 14.827999999999605 seconds of data due to short intervals. Remaining: 677 seconds.
# WARNING:root:Skipping 58.79056666666749 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 6.21216666666669 seconds of data due to short intervals. Remaining: 3314 seconds.
# 27it [50:03, 134.55s/it]WARNING:root:Skipping 0.01999999999998181 seconds of data due to short intervals. Remaining: 2590 seconds.
# WARNING:root:Skipping 4.857400000000553 seconds of data due to short intervals. Remaining: 2923 seconds.
# WARNING:root:Skipping 4.857400000000553 seconds of data due to short intervals. Remaining: 281 seconds.
# WARNING:root:Skipping 0.7238333333294196 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 0.49000000000023647 seconds of data due to short intervals. Remaining: 4 seconds.
# WARNING:root:Skipping 7.224800000000343 seconds of data due to short intervals. Remaining: 1440 seconds.
# WARNING:root:Skipping 13.055733333333535 seconds of data due to short intervals. Remaining: 1777 seconds.
# 28it [52:44, 142.50s/it]WARNING:root:Skipping 16.320000000000817 seconds of data due to short intervals. Remaining: 2395 seconds.
# WARNING:root:Skipping 16.320000000000817 seconds of data due to short intervals. Remaining: 577 seconds.
# WARNING:root:Skipping 58.30230000000298 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 8.251966666666448 seconds of data due to short intervals. Remaining: 3082 seconds.
# 29it [55:00, 140.70s/it]WARNING:root:Skipping 0.049999999999954525 seconds of data due to short intervals. Remaining: 670 seconds.
# WARNING:root:Skipping 0.08100000000001728 seconds of data due to short intervals. Remaining: 700 seconds.
# WARNING:root:Skipping 0.049999999999954525 seconds of data due to short intervals. Remaining: 8 seconds.
# WARNING:root:Skipping 0.08100000000001728 seconds of data due to short intervals. Remaining: 119 seconds.
# WARNING:root:Skipping 53.7354333333323 seconds of data due to short intervals. Remaining: 104 seconds.
# WARNING:root:Skipping 0.049999999999954525 seconds of data due to short intervals. Remaining: 8 seconds.
# WARNING:root:Skipping 7.216000000000072 seconds of data due to short intervals. Remaining: 234 seconds.
# WARNING:root:Skipping 0.9409999999999741 seconds of data due to short intervals. Remaining: 306 seconds.
# 30it [57:17, 139.65s/it]WARNING:root:Skipping 47.21249999999982 seconds of data due to short intervals. Remaining: 110 seconds.
# WARNING:root:Skipping 10.34956666666662 seconds of data due to short intervals. Remaining: 218 seconds.
# WARNING:root:Skipping 0.6972000000000094 seconds of data due to short intervals. Remaining: 306 seconds.
# 31it [58:27, 118.52s/it]WARNING:root:Skipping 1.0629999999998176 seconds of data due to short intervals. Remaining: 573 seconds.
# WARNING:root:Skipping 1.1820000000000164 seconds of data due to short intervals. Remaining: 620 seconds.
# WARNING:root:Skipping 0.862999999999829 seconds of data due to short intervals. Remaining: 4 seconds.
# WARNING:root:Skipping 1.1820000000000164 seconds of data due to short intervals. Remaining: 2 seconds.
# WARNING:root:Skipping 50.93333333333371 seconds of data due to short intervals. Remaining: 130 seconds.
# WARNING:root:Skipping 0.862999999999829 seconds of data due to short intervals. Remaining: 4 seconds.
# WARNING:root:Skipping
seconds of data due to short intervals. Remaining: 6 seconds.
# WARNING:root:Skipping 1.4646666666666306 seconds of data due to short intervals. Remaining: 358 seconds.
# WARNING:root:Skipping 2.2349999999999 seconds of data due to short intervals. Remaining: 434 seconds.
# 45it [1:21:27, 90.30s/it]WARNING:root:Skipping 0.47100000000000364 seconds of data due to short intervals. Remaining: 582 seconds.
# WARNING:root:Skipping 0.47100000000000364 seconds of data due to short intervals. Remaining: 49 seconds.
# WARNING:root:Skipping 41.74363333333328 seconds of data due to short intervals. Remaining: 116 seconds.
# WARNING:root:Skipping 0.770433333333358 seconds of data due to short intervals. Remaining: 232 seconds.
# WARNING:root:Skipping 0.8369999999999891 seconds of data due to short intervals. Remaining: 281 seconds.
# 46it [1:23:25, 98.45s/it]WARNING:root:Skipping 46.47139999999965 seconds of data due to short intervals. Remaining: 144 seconds.
# WARNING:root:Skipping 3.9482000000001563 seconds of data due to short intervals. Remaining: 262 seconds.
# WARNING:root:Skipping 1.0399999999999991 seconds of data due to short intervals. Remaining: 314 seconds.
# 47it [1:24:52, 95.02s/it]WARNING:root:Skipping 46.80200000000025 seconds of data due to short intervals. Remaining: 130 seconds.
# WARNING:root:Skipping 2.9301333333332877 seconds of data due to short intervals. Remaining: 256 seconds.
# WARNING:root:Skipping 0.9399999999999409 seconds of data due to short intervals. Remaining: 315 seconds.
# 48it [1:25:52, 84.56s/it]WARNING:root:Skipping 0.52800000000002 seconds of data due to short intervals. Remaining: 527 seconds.
# WARNING:root:Skipping 0.52800000000002 seconds of data due to short intervals. Remaining: 5 seconds.
# WARNING:root:Skipping 44.468300000000006 seconds of data due to short intervals. Remaining: 142 seconds.
# WARNING:root:Skipping 0.52800000000002 seconds of data due to short intervals. Remaining: 5 seconds.
# WARNING:root:Skipping 7.754399999999919 seconds of data due to short intervals. Remaining: 248 seconds.
# 49it [1:27:19, 85.29s/it]WARNING:root:Skipping 0.39400000000000546 seconds of data due to short intervals. Remaining: 484 seconds.
# WARNING:root:Skipping 0.39400000000000546 seconds of data due to short intervals. Remaining: 6 seconds.
# WARNING:root:Skipping 41.09013333333313 seconds of data due to short intervals. Remaining: 122 seconds.
# WARNING:root:Skipping 0.39400000000000546 seconds of data due to short intervals. Remaining: 6 seconds.
# WARNING:root:Skipping 0.09699999999997999 seconds of data due to short intervals. Remaining: 277 seconds.
# 50it [1:28:44, 85.23s/it]WARNING:root:Skipping 0.37999999999999545 seconds of data due to short intervals. Remaining: 508 seconds.
# WARNING:root:Skipping 0.15953333333334285 seconds of data due to short intervals. Remaining: 556 seconds.
# WARNING:root:Skipping 0.37999999999999545 seconds of data due to short intervals. Remaining: 4 seconds.
# WARNING:root:Skipping 0.15953333333334285 seconds of data due to short intervals. Remaining: 556 seconds.
# WARNING:root:Skipping 45.880999999999936 seconds of data due to short intervals. Remaining: 124 seconds.
# WARNING:root:Skipping 0.37999999999999545 seconds of data due to short intervals. Remaining: 4 seconds.
# 51it [1:30:12, 86.11s/it]WARNING:root:Skipping 0.6725999999998749 seconds of data due to short intervals. Remaining: 638 seconds.
# WARNING:root:Skipping 0.6725999999998749 seconds of data due to short intervals. Remaining: 638 seconds.
# WARNING:root:Skipping 52.93619999999959 seconds of data due to short intervals. Remaining: 138 seconds.
# WARNING:root:Skipping 1.983366666666683 seconds of data due to short intervals. Remaining: 280 seconds.
# WARNING:root:Skipping 1.1214000000000226 seconds of data due to short intervals. Remaining: 342 seconds.
# 52it [1:31:41, 86.91s/it]WARNING:root:Skipping 0.12373333333323444 seconds of data due to short intervals. Remaining: 537 seconds.
# WARNING:root:Skipping 0.12373333333323444 seconds of data due to short intervals. Remaining: 537 seconds.
# WARNING:root:Skipping 39.20576666666634 seconds of data due to short intervals. Remaining: 126 seconds.
# WARNING:root:Skipping 1.9749000000000194 seconds of data due to short intervals. Remaining: 230 seconds.
# WARNING:root:Skipping 1.0929333333333346 seconds of data due to short intervals. Remaining: 279 seconds.
# 53it [1:33:09, 87.35s/it]WARNING:root:Skipping 48.68996666666668 seconds of data due to short intervals. Remaining: 140 seconds.
# WARNING:root:Skipping 0.4900000000000091 seconds of data due to short intervals. Remaining: 5 seconds.
# WARNING:root:Skipping 2.9425666666666643 seconds of data due to short intervals. Remaining: 266 seconds.
# WARNING:root:Skipping 2.984999999999978 seconds of data due to short intervals. Remaining: 293 seconds.
# 54it [1:35:20, 100.36s/it]WARNING:root:Skipping 0.07500000000004547 seconds of data due to short intervals. Remaining: 532 seconds.
# WARNING:root:Skipping 0.07500000000004547 seconds of data due to short intervals. Remaining: 25 seconds.
# WARNING:root:Skipping 44.234233333333954 seconds of data due to short intervals. Remaining: 101 seconds.
# WARNING:root:Skipping 9.631233333333242 seconds of data due to short intervals. Remaining: 247 seconds.
# 55it [1:38:14, 122.43s/it]WARNING:root:Skipping 0.07000000000000739 seconds of data due to short intervals. Remaining: 649 seconds.
# WARNING:root:Skipping 0.07000000000000739 seconds of data due to short intervals. Remaining: 675 seconds.
# WARNING:root:Skipping 0.07000000000000739 seconds of data due to short intervals. Remaining: 20 seconds.
# WARNING:root:Skipping 52.607799999999976 seconds of data due to short intervals. Remaining: 152 seconds.
# WARNING:root:Skipping 0.4900000000000091 seconds of data due to short intervals. Remaining: 6 seconds.
# WARNING:root:Skipping 12.896000000000328 seconds of data due to short intervals. Remaining: 305 seconds.
# 56it [1:42:16, 158.43s/it]WARNING:root:Skipping 45.868299999999635 seconds of data due to short intervals. Remaining: 146 seconds.
# WARNING:root:Skipping 5.767999999999994 seconds of data due to short intervals. Remaining: 294 seconds.
# 57it [1:45:35, 170.59s/it]WARNING:root:Skipping 43.829033333333385 seconds of data due to short intervals. Remaining: 130 seconds.
# WARNING:root:Skipping 7.135000000000055 seconds of data due to short intervals. Remaining: 262 seconds.
# 58it [1:50:12, 202.28s/it]WARNING:root:Skipping 0.18299999999999272 seconds of data due to short intervals. Remaining: 548 seconds.
# WARNING:root:Skipping 0.18299999999999272 seconds of data due to short intervals. Remaining: 7 seconds.
# WARNING:root:Skipping 46.8575999999999 seconds of data due to short intervals. Remaining: 132 seconds.
# WARNING:root:Skipping 0.18299999999999272 seconds of data due to short intervals. Remaining: 7 seconds.
# WARNING:root:Skipping 5.777999999999878 seconds of data due to short intervals. Remaining: 282 seconds.
# 59it [1:54:25, 217.68s/it]WARNING:root:Skipping 43.75683333333364 seconds of data due to short intervals. Remaining: 128 seconds.
# WARNING:root:Skipping 0.14049999999997453 seconds of data due to short intervals. Remaining: 248 seconds.
# WARNING:root:Skipping 9.990999999999815 seconds of data due to short intervals. Remaining: 249 seconds.
# 60it [1:58:57, 233.91s/it]WARNING:root:Skipping 0.3830000000000382 seconds of data due to short intervals. Remaining: 564 seconds.
# /cs/student/projects1/ml/2024/mlaimon/anaconda3/envs/foundational_ssm/lib/python3.13/site-packages/scipy/interpolate/_interpolate.py:479: RuntimeWarning: divide by zero encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# /cs/student/projects1/ml/2024/mlaimon/anaconda3/envs/foundational_ssm/lib/python3.13/site-packages/scipy/interpolate/_interpolate.py:482: RuntimeWarning: invalid value encountered in multiply
#   y_new = slope*(x_new - x_lo)[:, None] + y_lo
# WARNING:root:Skipping 0.05999999999994543 seconds of data due to short intervals. Remaining: 618 seconds.
# WARNING:root:Skipping 0.32300000000009277 seconds of data due to short intervals. Remaining: 4 seconds.
# WARNING:root:Skipping 0.05999999999994543 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 52.818666666666815 seconds of data due to short intervals. Remaining: 138 seconds.
# WARNING:root:Skipping 0.32300000000009277 seconds of data due to short intervals. Remaining: 4 seconds.
# WARNING:root:Skipping 1.0424333333333493 seconds of data due to short intervals. Remaining: 284 seconds.
# WARNING:root:Skipping 8.656999999999975 seconds of data due to short intervals. Remaining: 288 seconds.
# 61it [2:02:29, 227.22s/it]WARNING:root:Skipping 0.04399999999998272 seconds of data due to short intervals. Remaining: 585 seconds.
# WARNING:root:Skipping 0.9198666666666213 seconds of data due to short intervals. Remaining: 643 seconds.
# WARNING:root:Skipping 0.04399999999998272 seconds of data due to short intervals. Remaining: 5 seconds.
# WARNING:root:Skipping 0.9198666666666213 seconds of data due to short intervals. Remaining: 639 seconds.
# WARNING:root:Skipping 56.30703333333345 seconds of data due to short intervals. Remaining: 138 seconds.
# WARNING:root:Skipping 0.04399999999998272 seconds of data due to short intervals. Remaining: 5 seconds.
# WARNING:root:Skipping 0.3915666666665629 seconds of data due to short intervals. Remaining: 294 seconds.
# WARNING:root:Skipping 4.093999999999959 seconds of data due to short intervals. Remaining: 318 seconds.
# 62it [2:06:34, 232.55s/it]WARNING:root:Skipping 1.05600000000004 seconds of data due to short intervals. Remaining: 655 seconds.
# WARNING:root:Skipping 1.05600000000004 seconds of data due to short intervals. Remaining: 32 seconds.
# WARNING:root:Skipping 52.38043333333337 seconds of data due to short intervals. Remaining: 144 seconds.
# WARNING:root:Skipping 0.5624000000000251 seconds of data due to short intervals. Remaining: 286 seconds.
# WARNING:root:Skipping 5.7680000000000575 seconds of data due to short intervals. Remaining: 300 seconds.
# 63it [2:10:05, 226.20s/it]WARNING:root:Skipping 53.048133333333496 seconds of data due to short intervals. Remaining: 148 seconds.
# WARNING:root:Skipping 0.5381666666666671 seconds of data due to short intervals. Remaining: 3 seconds.
# WARNING:root:Skipping 0.9997999999999934 seconds of data due to short intervals. Remaining: 292 seconds.
# WARNING:root:Skipping 6.46199999999989 seconds of data due to short intervals. Remaining: 323 seconds.
# 64it [2:12:11, 196.18s/it]WARNING:root:Skipping 39.267699999999934 seconds of data due to short intervals. Remaining: 126 seconds.
# WARNING:root:Skipping 0.6374333333333482 seconds of data due to short intervals. Remaining: 234 seconds.
# WARNING:root:Skipping 3.8399999999999075 seconds of data due to short intervals. Remaining: 249 seconds.
# 65it [2:13:53, 167.83s/it]WARNING:root:Skipping 0.4819999999999709 seconds of data due to short intervals. Remaining: 643 seconds.
# WARNING:root:Skipping 0.4819999999999709 seconds of data due to short intervals. Remaining: 27 seconds.
# WARNING:root:Skipping 50.155466666666655 seconds of data due to short intervals. Remaining: 138 seconds.
# WARNING:root:Skipping 2.721733333333276 seconds of data due to short intervals. Remaining: 308 seconds.
# 66it [2:15:52, 153.37s/it]WARNING:root:Skipping 2.2529999999999575 seconds of data due to short intervals. Remaining: 941 seconds.
# WARNING:root:Skipping 2.2529999999999575 seconds of data due to short intervals. Remaining: 448 seconds.
# WARNING:root:Skipping 15.996233333334452 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 0.6211666666666815 seconds of data due to short intervals. Remaining: 1244 seconds.
# 67it [2:17:32, 137.41s/it]WARNING:root:Skipping 1.661999999999935 seconds of data due to short intervals. Remaining: 937 seconds.
# WARNING:root:Skipping 0.48299999999994725 seconds of data due to short intervals. Remaining: 545 seconds.
# WARNING:root:Skipping 1.1789999999999878 seconds of data due to short intervals. Remaining: 392 seconds.
# WARNING:root:Skipping 17.307099999999974 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 0.38209999999992306 seconds of data due to short intervals. Remaining: 1238 seconds.
# 68it [2:19:09, 125.24s/it]WARNING:root:Skipping 2.3869999999998583 seconds of data due to short intervals. Remaining: 760 seconds.
# WARNING:root:Skipping 0.6529999999999063 seconds of data due to short intervals. Remaining: 417 seconds.
# WARNING:root:Skipping 1.733999999999952 seconds of data due to short intervals. Remaining: 343 seconds.
# WARNING:root:Skipping 12.956766666667384 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 0.5521666666664942 seconds of data due to short intervals. Remaining: 1022 seconds.
# 69it [2:20:47, 116.96s/it]WARNING:root:Skipping 40.84729999999999 seconds of data due to short intervals. Remaining: 116 seconds.
# WARNING:root:Skipping 0.9580333333333328 seconds of data due to short intervals. Remaining: 224 seconds.
# 70it [2:22:15, 108.20s/it]WARNING:root:Skipping 2.2809999999999206 seconds of data due to short intervals. Remaining: 803 seconds.
# WARNING:root:Skipping 2.2809999999999206 seconds of data due to short intervals. Remaining: 340 seconds.
# WARNING:root:Skipping 13.874099999999851 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 0.33663333333333867 seconds of data due to short intervals. Remaining: 1049 seconds.
# 71it [2:23:50, 104.42s/it]WARNING:root:Skipping 43.08703333333302 seconds of data due to short intervals. Remaining: 126 seconds.
# WARNING:root:Skipping 2.7761333333332914 seconds of data due to short intervals. Remaining: 238 seconds.
# WARNING:root:Skipping 1.033999999999935 seconds of data due to short intervals. Remaining: 326 seconds.
# 72it [2:25:36, 104.88s/it]WARNING:root:Skipping 0.09093333333316878 seconds of data due to short intervals. Remaining: 729 seconds.
# WARNING:root:Skipping 0.09093333333316878 seconds of data due to short intervals. Remaining: 729 seconds.
# WARNING:root:Skipping 56.6552999999994 seconds of data due to short intervals. Remaining: 142 seconds.
# WARNING:root:Skipping 0.9645999999999901 seconds of data due to short intervals. Remaining: 296 seconds.
# 73it [2:27:10, 101.43s/it]WARNING:root:Skipping 2.417999999999722 seconds of data due to short intervals. Remaining: 651 seconds.
# WARNING:root:Skipping 0.43499999999983174 seconds of data due to short intervals. Remaining: 420 seconds.
# WARNING:root:Skipping 1.9829999999998904 seconds of data due to short intervals. Remaining: 231 seconds.
# WARNING:root:Skipping 13.770433333333253 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 1.5715333333332546 seconds of data due to short intervals. Remaining: 881 seconds.
# 74it [2:28:30, 95.14s/it] WARNING:root:Skipping 4.6189999999999145 seconds of data due to short intervals. Remaining: 524 seconds.
# WARNING:root:Skipping 4.6189999999999145 seconds of data due to short intervals. Remaining: 183 seconds.
# WARNING:root:Skipping 11.645366666666442 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 0.49 seconds of data due to short intervals. Remaining: 745 seconds.
# 75it [2:30:02, 94.28s/it]WARNING:root:Skipping 0.5525333333331446 seconds of data due to short intervals. Remaining: 687 seconds.
# WARNING:root:Skipping 0.5525333333331446 seconds of data due to short intervals. Remaining: 687 seconds.
# WARNING:root:Skipping 52.73339999999981 seconds of data due to short intervals. Remaining: 140 seconds.
# WARNING:root:Skipping 0.9956666666665797 seconds of data due to short intervals. Remaining: 280 seconds.
# 76it [2:31:31, 92.70s/it]WARNING:root:Skipping 0.9670000000000982 seconds of data due to short intervals. Remaining: 622 seconds.
# WARNING:root:Skipping 0.9670000000000982 seconds of data due to short intervals. Remaining: 35 seconds.
# WARNING:root:Skipping 42.90420000000019 seconds of data due to short intervals. Remaining: 118 seconds.
# WARNING:root:Skipping 0.9670000000000982 seconds of data due to short intervals. Remaining: 35 seconds.
# WARNING:root:Skipping 0.7690000000000055 seconds of data due to short intervals. Remaining: 359 seconds.
# 77it [2:33:01, 91.73s/it]WARNING:root:Skipping 48.163699999999494 seconds of data due to short intervals. Remaining: 132 seconds.
# WARNING:root:Skipping 0.1375666666666575 seconds of data due to short intervals. Remaining: 266 seconds.
# WARNING:root:Skipping 1.1165000000000873 seconds of data due to short intervals. Remaining: 341 seconds.
# 78it [2:34:30, 91.09s/it]WARNING:root:Skipping 48.52556666666648 seconds of data due to short intervals. Remaining: 138 seconds.
# WARNING:root:Skipping 0.870900000000006 seconds of data due to short intervals. Remaining: 272 seconds.
# WARNING:root:Skipping 0.8269999999999413 seconds of data due to short intervals. Remaining: 349 seconds.
# 79it [2:36:02, 91.24s/it]WARNING:root:Skipping 163.4609333333301 seconds of data due to short intervals. Remaining: 470 seconds.
# WARNING:root:Skipping 0.4899999999997817 seconds of data due to short intervals. Remaining: 27 seconds.
# WARNING:root:Skipping 1.894033333333482 seconds of data due to short intervals. Remaining: 898 seconds.
# 80it [2:38:03, 100.12s/it]WARNING:root:Skipping 155.2202000000037 seconds of data due to short intervals. Remaining: 456 seconds.
# WARNING:root:Skipping 1.8235333333332164 seconds of data due to short intervals. Remaining: 870 seconds.
# WARNING:root:Skipping 1.6221333333331103 seconds of data due to short intervals. Remaining: 1183 seconds.
# 81it [2:40:16, 110.07s/it]WARNING:root:Skipping 0.5167000000001281 seconds of data due to short intervals. Remaining: 2492 seconds.
# WARNING:root:Skipping 0.5167000000001281 seconds of data due to short intervals. Remaining: 34 seconds.
# WARNING:root:Skipping 192.408966666666 seconds of data due to short intervals. Remaining: 521 seconds.
# WARNING:root:Skipping 3.1678666666667823 seconds of data due to short intervals. Remaining: 1032 seconds.
# WARNING:root:Skipping 3.1632999999999356 seconds of data due to short intervals. Remaining: 1332 seconds.
# 82it [2:42:24, 115.42s/it]WARNING:root:Skipping 53.08829999999952 seconds of data due to short intervals. Remaining: 162 seconds.
# WARNING:root:Skipping 0.4900000000000091 seconds of data due to short intervals. Remaining: 71 seconds.
# 83it [2:44:44, 122.75s/it]WARNING:root:Skipping 0.1999999999998181 seconds of data due to short intervals. Remaining: 2419 seconds.
# WARNING:root:Skipping 0.1999999999998181 seconds of data due to short intervals. Remaining: 2435 seconds.
# WARNING:root:Skipping 0.1999999999998181 seconds of data due to short intervals. Remaining: 119 seconds.
# WARNING:root:Skipping 172.5125333333303 seconds of data due to short intervals. Remaining: 497 seconds.
# WARNING:root:Skipping 0.2566666666666606 seconds of data due to short intervals. Remaining: 1271 seconds.
# 84it [2:48:03, 145.60s/it]WARNING:root:Skipping 45.16606666666651 seconds of data due to short intervals. Remaining: 130 seconds.
# WARNING:root:Skipping 0.2761333333332914 seconds of data due to short intervals. Remaining: 254 seconds.
# WARNING:root:Skipping 0.8530000000000086 seconds of data due to short intervals. Remaining: 321 seconds.
# 85it [2:50:38, 148.53s/it]WARNING:root:Skipping 41.81266666666681 seconds of data due to short intervals. Remaining: 132 seconds.
# WARNING:root:Skipping 0.9215666666665356 seconds of data due to short intervals. Remaining: 244 seconds.
# 86it [2:53:11, 149.89s/it]WARNING:root:Skipping 0.12000000000000455 seconds of data due to short intervals. Remaining: 522 seconds.
# WARNING:root:Skipping 0.27559999999994034 seconds of data due to short intervals. Remaining: 548 seconds.
# WARNING:root:Skipping 0.1555999999999358 seconds of data due to short intervals. Remaining: 548 seconds.
# WARNING:root:Skipping 0.12000000000000455 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 35.42819999999976 seconds of data due to short intervals. Remaining: 132 seconds.
# 87it [2:55:19, 143.08s/it]WARNING:root:Skipping 34.92276666666651 seconds of data due to short intervals. Remaining: 118 seconds.
# WARNING:root:Skipping 1.5239999999999014 seconds of data due to short intervals. Remaining: 256 seconds.
# 88it [2:57:13, 134.60s/it]WARNING:root:Skipping 0.1400000000000432 seconds of data due to short intervals. Remaining: 505 seconds.
# WARNING:root:Skipping 0.1400000000000432 seconds of data due to short intervals. Remaining: 551 seconds.
# WARNING:root:Skipping 0.1400000000000432 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 41.66533333333308 seconds of data due to short intervals. Remaining: 128 seconds.
# WARNING:root:Skipping 0.9259999999999309 seconds of data due to short intervals. Remaining: 294 seconds.
# 89it [2:59:18, 131.70s/it]WARNING:root:Skipping 0.9690000000000509 seconds of data due to short intervals. Remaining: 489 seconds.
# WARNING:root:Skipping 0.9690000000000509 seconds of data due to short intervals. Remaining: 4 seconds.
# WARNING:root:Skipping 43.01073333333343 seconds of data due to short intervals. Remaining: 114 seconds.
# WARNING:root:Skipping 0.9690000000000509 seconds of data due to short intervals. Remaining: 4 seconds.
# WARNING:root:Skipping 1.1159999999999854 seconds of data due to short intervals. Remaining: 282 seconds.
# 90it [3:01:28, 131.07s/it]WARNING:root:Skipping 38.02743333333335 seconds of data due to short intervals. Remaining: 158 seconds.
# WARNING:root:Skipping 0.9187999999999192 seconds of data due to short intervals. Remaining: 260 seconds.
# WARNING:root:Skipping 1.6999999999999602 seconds of data due to short intervals. Remaining: 315 seconds.
# 91it [3:03:14, 123.48s/it]WARNING:root:Skipping 46.793033333333355 seconds of data due to short intervals. Remaining: 120 seconds.
# WARNING:root:Skipping 2.1389999999998963 seconds of data due to short intervals. Remaining: 283 seconds.
# 92it [3:05:11, 121.70s/it]WARNING:root:Skipping 42.93156666666661 seconds of data due to short intervals. Remaining: 140 seconds.
# WARNING:root:Skipping 0.3129999999999882 seconds of data due to short intervals. Remaining: 298 seconds.
# 93it [3:06:13, 103.70s/it]WARNING:root:Skipping 0.4661999999999864 seconds of data due to short intervals. Remaining: 233 seconds.
# WARNING:root:Skipping 0.4661999999999864 seconds of data due to short intervals. Remaining: 233 seconds.
# 138it [3:16:00, 16.48s/it]WARNING:root:Skipping 0.43016666666682113 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 541.0069999999989 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 462.69399999999536 seconds of data due to short intervals. Remaining: 2 seconds.
# WARNING:root:Skipping 0.7625922803690628 seconds of data due to short intervals. Remaining: 2244 seconds.
# 139it [3:18:43, 60.58s/it]WARNING:root:Skipping 1.4416666666642186 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 793.4780000000034 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 669.1099999999988 seconds of data due to short intervals. Remaining: 8 seconds.
# 140it [3:23:42, 132.15s/it]WARNING:root:Skipping 1.1292999999959648 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 1188.134999999976 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 842.3600000000172 seconds of data due to short intervals. Remaining: 36 seconds.
# 141it [3:29:25, 195.29s/it]WARNING:root:Skipping 0.8737309161297162 seconds of data due to short intervals. Remaining: 6834 seconds.
# WARNING:root:Skipping 0.8737309161297162 seconds of data due to short intervals. Remaining: 6833 seconds.
# WARNING:root:Skipping 0.5558666666679528 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 0.8737309161297162 seconds of data due to short intervals. Remaining: 6731 seconds.
# WARNING:root:Skipping 800.5687309161542 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 662.2969999999941 seconds of data due to short intervals. Remaining: 10 seconds.
# 142it [3:35:05, 238.82s/it]WARNING:root:Skipping 0.9720642292486446 seconds of data due to short intervals. Remaining: 10049 seconds.
# WARNING:root:Skipping 0.9720642292486446 seconds of data due to short intervals. Remaining: 10048 seconds.
# WARNING:root:Skipping 1.2191000000038912 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 0.9720642292486446 seconds of data due to short intervals. Remaining: 9920 seconds.
# WARNING:root:Skipping 1169.9530642292689 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 985.2849999999983 seconds of data due to short intervals. Remaining: 0 seconds.
# 143it [3:43:25, 317.21s/it]WARNING:root:Skipping 5.368400000004726 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 132.22199999997267 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 1033.944000000017 seconds of data due to short intervals. Remaining: 0 seconds.
# 144it [3:50:14, 344.61s/it]WARNING:root:Skipping 0.0337982926521363 seconds of data due to short intervals. Remaining: 9613 seconds.
# WARNING:root:Skipping 0.0337982926521363 seconds of data due to short intervals. Remaining: 9613 seconds.
# WARNING:root:Skipping 0.2951999999995749 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 0.0337982926521363 seconds of data due to short intervals. Remaining: 9410 seconds.
# WARNING:root:Skipping 1337.9419999999188 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 906.4680000000008 seconds of data due to short intervals. Remaining: 0 seconds.
# 145it [3:57:14, 367.14s/it]WARNING:root:Skipping 0.6044010588793753 seconds of data due to short intervals. Remaining: 11988 seconds.
# WARNING:root:Skipping 2.45513439221304 seconds of data due to short intervals. Remaining: 11975 seconds.
# WARNING:root:Skipping 10.998833333332826 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 0.6044010588793753 seconds of data due to short intervals. Remaining: 7742 seconds.
# WARNING:root:Skipping 1.8507333333336646 seconds of data due to short intervals. Remaining: 4233 seconds.
# WARNING:root:Skipping 596.4119999999826 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 1000.4490000000014 seconds of data due to short intervals. Remaining: 4 seconds.
# WARNING:root:Skipping 1.3018333333329792 seconds of data due to short intervals. Remaining: 3836 seconds.
# 146it [4:05:38, 408.46s/it]WARNING:root:Skipping 0.915366666666614 seconds of data due to short intervals. Remaining: 7982 seconds.
# WARNING:root:Skipping 5.210466666657339 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 0.915366666666614 seconds of data due to short intervals. Remaining: 1488 seconds.
# WARNING:root:Skipping 515.1830000000073 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 822.563999999994 seconds of data due to short intervals. Remaining: 2 seconds.
# WARNING:root:Skipping 0.9188824559387285 seconds of data due to short intervals. Remaining: 3224 seconds.
# 147it [4:12:20, 406.27s/it]WARNING:root:Skipping 0.10168666666504578 seconds of data due to short intervals. Remaining: 12503 seconds.
# WARNING:root:Skipping 0.10168666666504578 seconds of data due to short intervals. Remaining: 12499 seconds.
# WARNING:root:Skipping 4.571999999998525 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 0.10168666666504578 seconds of data due to short intervals. Remaining: 12108 seconds.
# WARNING:root:Skipping 1722.4280000000376 seconds of data due to short intervals. Remaining: 0 seconds.
# WARNING:root:Skipping 1263.6399999999335 seconds of data due to short intervals. Remaining: 0 seconds.
# 148it [4:26:17, 107.96s/it]

# %%
recording_metrics_df = pd.DataFrame(recording_metrics_list[3:])

# %%
recording_metrics_df.to_csv('recording_metrics.csv')

# %%
from functools import partial


# Create a pandas dataframe of sessions holding the following columns:
# Info: 1. dataset 
# Stats: per ('within-trial', 'inter-trial'); movement_phases (hold_period', 'invalid', 'random_period', 'reach_period', 'return_period')
#   - duration,, 
#   - variance
#   - mse/r2. this can be done by getting predictions over the entire duration using sequentialfixedwindowsampler.
train_dataset.transform = transform_brainsets_regular_time_series_smoothed
train_window_length = 1 
val_window_length = 6
sampling_rate = 200



for recording_id, sampling_interval in train_sampling_intervals.items():
    recording_data = train_dataset.get_recording_data(recording_id) 
    variance, mse, r2 = compute_train_variance_mse_r2(train_dataset,
                                                    sampling_intervals = {recording_id: sampling_interval},
                                                    model=model,
                                                    state=state
                                                    )
    if hasattr(recording_data, "trials"):
        if hasattr(recording_data.trials, "is_valid"):
            valid_trial_intervals = recording_data.trials.select_by_mask(recording_data.trials.is_valid)
        else:
            valid_trial_intervals = recording_data.trials
        ex_valid_trial_intervals = sampling_interval.difference(valid_trial_intervals)
        
        trial_duration = (valid_trial_intervals.end - valid_trial_intervals.start).sum()
        ex_trial_duration = (ex_valid_trial_intervals.end - ex_valid_trial_intervals.start).sum()
        
        
        
    
    # split by within trial and outside of trial 
    # recording_data.select_by_interval ()
    # get total durations 
    # get variance
    # get prediction errors. 
    
    
    
    # split by movement phases 
    
    # get total durations for each, variances, and prediction errors. 
    
    break
# Out:
# /tmp/ipykernel_42813/3192923505.py:45: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   batch = {k: jax.device_put(np.array(v)) for k, v in batch.items()}
# dict_keys(['neural_input', 'behavior_input', 'mask', 'dataset_group_idx'])
# dict_keys(['neural_input', 'behavior_input', 'mask', 'dataset_group_idx'])

# %%
mse
# Out:
# Array([662.4436, 450.7957], dtype=float32)

# %%
print(content.decode())
# Out:
# ---------------------------------------------------------------------------
#
# UnicodeDecodeError                        Traceback (most recent call last)
#
# Cell In[27], line 1
#
# ----> 1 print(content.decode())
#
#
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x93 in position 0: invalid start byte

# %%
for movement_phase in recording_data.movement_phases.keys():
# Out:
# ['hold_period', 'invalid', 'random_period', 'reach_period', 'return_period']
